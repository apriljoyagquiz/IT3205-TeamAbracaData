# %% [markdown]
# <a href="https://colab.research.google.com/github/apriljoyagquiz/IT3205-TeamAbracaData/blob/main/OFW_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Overseas Filipino Workers 2019-2020**
#
# *Source: Philippine Statistics Authority*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Filipino%20Overseas%20Workers%20by%20Sex%20and%20Group%20Age%20Group%20by%202019%20and%202020.csv'
data = pd.read_csv(url)
display(data.iloc[0:])
# Out:
#      Age_Group  Both_Sexes_Estimate_2019  Male_Estimate_19  \
# 0      15 - 24                       6.3               5.5
# 1      25 - 29                      20.3              18.8
# 2      30 - 34                      22.3              19.5
# 3      35 - 39                      18.8              18.0
# 4      40 - 44                      14.2              16.4
# 5  45 and over                      18.0              21.8
#
#    Female_Estimate_19  Both_Sexes_Estimate_2020  Male_Estimate_20  \
# 0                 7.0                       3.8               2.9
# 1                21.6                      19.0              18.9
# 2                24.6                      22.4              21.2
# 3                19.5                      20.5              18.0
# 4                12.5                      15.2              15.6
# 5                14.9                      19.1              23.3
#
#    Female_Estimate_20
# 0                 4.4
# 1                19.0
# 2                23.3
# 3                22.2
# 4                14.9
# 5                16.2

# %% [markdown]
# #Age Group by Sex of Overseas Filipino Workers 2019-2020

# %%
data.columns
# Out:
# Index(['Age_Group', 'Both_Sexes_Estimate_2019', 'Male_Estimate_19',
#        'Female_Estimate_19', 'Both_Sexes_Estimate_2020', 'Male_Estimate_20',
#        'Female_Estimate_20'],
#       dtype='object')

# %%
#Changing the size of the visualization
plt.figure(figsize=(8,5), facecolor='yellow')

#Creating the plot
plt.plot(data.Age_Group, data.Both_Sexes_Estimate_2019,'g.-', label=2019, linewidth = 2 )
plt.plot(data.Age_Group, data.Both_Sexes_Estimate_2020, 'y.-', label=2020, linewidth = 2)
plt.xlabel("Age Group")
plt.ylabel("Estimate")
plt.title("Both Sexes Estimate 2019-2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':18})
plt.grid(color='orange', linestyle='--', linewidth = 0.9)
plt.legend()
plt.show()

# %%
#Changing the size of the visualization
plt.figure(figsize=(8,5), facecolor='skyblue')

#Creating the plot
plt.plot(data.Age_Group, data.Male_Estimate_19, 'c.-', label=2019, linewidth = 2)
plt.plot(data.Age_Group, data.Male_Estimate_20, 'b.-', label=2020, linewidth = 2)
plt.xlabel("Age Group")
plt.ylabel("Estimate")
plt.title("Male Estimate 2019-2020", fontdict={'fontname': 'DejaVu Sans', 'fontweight':'bold', 'fontsize':18})
plt.grid(color='skyblue', linestyle='--', linewidth = 0.9)
plt.legend()
plt.show()

# %%
#Changing the size of the visualization
plt.figure(figsize=(8,5), facecolor='lightpink')

#Creating the plot
plt.plot(data.Age_Group, data.Female_Estimate_19,'r.-',  label=2019, linewidth = 2)
plt.plot(data.Age_Group, data.Female_Estimate_20,'m.-',  label=2020, linewidth = 2)
plt.xlabel("Age Group")
plt.ylabel("Estimate")
plt.title("Female Estimate 2019-2020", fontdict={'fontname': 'DejaVu Sans', 'fontweight':'bold', 'fontsize':18})
plt.grid(color='pink', linestyle='--', linewidth = 0.9)
plt.legend()
plt.show()

# %%
Age_Group = data['Age_Group']

Male_Estimate_19 = data ['Male_Estimate_19']
Female_Estimate_19 = data ['Female_Estimate_19']

xpos =np.arange(len(Age_Group))

# %%
#Changing the size of the visualization
style.use ('ggplot')
plt.figure(figsize=(35,15))
barWidth = 0.3

#Creating the plot
plt.bar(xpos, Male_Estimate_19, color='brown', width =barWidth, label='Male in 2019' )
plt.bar(xpos+0.3, Female_Estimate_19, color='lightcoral', width =barWidth, label='Female in 2019' )
plt.title("Male and Female Estimate in 2019", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.xticks(xpos+0.1,('15-24', '25-29', '30-34', '35-39', '40-44', '45 and over'))
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Estimate', fontsize=15)
plt.yticks()
plt.legend()
plt.show()

# %%
Age_Group = data['Age_Group']

Male_Estimate_20 = data ['Male_Estimate_20']
Female_Estimate_20 = data ['Female_Estimate_20']

xpos =np.arange(len(Age_Group))

# %%
#Changing the size of the visualization
style.use ('ggplot')
plt.figure(figsize=(35,15))
barWidth = 0.3

#Creating the plot
plt.bar(xpos, Male_Estimate_20, color='seagreen', width =barWidth, label='Male in 2020' )
plt.bar(xpos+0.3, Female_Estimate_20, color='mediumturquoise', width =barWidth, label='Female in 2020' )
plt.title("Male and Female Estimate in 2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.xticks(xpos+0.1,('15-24', '25-29', '30-34', '35-39', '40-44', '45 and over'))
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Estimate', fontsize=15)
plt.yticks()
plt.legend()
plt.show()

# %% [markdown]
# ## **Occupation of Overseas Filipino Workers: 2019-2020**

# %%
url = 'https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Overseas%20Filipino%20Workers%20by%20Occupation%202019-2020.csv'

# %%
occupation = pd.read_csv(url)
display(occupation.iloc[0:])
# Out:
#                                     Major_Occupation  \
# 0                                           Managers
# 1                                      Professionals
# 2            Technicians and associate professionals
# 3                           Clerical support workers
# 4                          Service and sales workers
# 5  Skilled agricultural forestry and fishery workers
# 6                    Craft and related trade workers
# 7         Plant and machine operators and assemblers
# 8                             Elementary occupations
#
#    Both_Sexes_Estimate_2019  Male_Estimate  Female_Estimate  \
# 0                       1.1            1.1              1.1
# 1                       8.5            6.9              9.8
# 2                       8.9           17.4              2.0
# 3                       3.5            3.1              3.8
# 4                      17.6           17.3             17.8
# 5                       0.8            1.8              0.1
# 6                       8.3           17.4              0.9
# 7                      12.3           24.6              2.4
# 8                      39.0           10.4             62.1
#
#    Both_Sexes_Estimate_2020  Male_Estimate_20  Female_Estimate_20
# 0                       1.5               1.5                 1.4
# 1                       8.2               9.6                 7.3
# 2                       6.7              13.9                 1.8
# 3                       3.8               3.4                 4.2
# 4                      14.4              17.0                12.6
# 5                       0.4               0.7                 0.1
# 6                       6.8              15.9                 0.7
# 7                      11.5              26.0                 1.7
# 8                      46.7              12.0                70.3

# %%
#Changing the size of the visualization
plt.figure(figsize=(35,15))

#Creating the plot
plt.plot(occupation.Major_Occupation, occupation.Both_Sexes_Estimate_2019, 'r.-', label=2019, linewidth = 10)
plt.plot(occupation.Major_Occupation, occupation.Both_Sexes_Estimate_2020, label=2020, linewidth = 10)
plt.xlabel=("Major Occupation")
plt.ylabel("Estimates", fontdict={'fontsize':25})
plt.title("Estimate Comparison for Both Sexes: 2019-2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.grid(color='green', linestyle='--', linewidth = 1)
plt.legend(loc=2)
plt.show()

# %%
#Size of the entire graph
f = plt.figure()
f.set_figwidth(32)
f.set_figheight(15)
plt.grid(linewidth=1, color='green', linestyle='--')

#Creating the plot
plt.scatter(occupation.Major_Occupation, occupation.Male_Estimate, s=200, c='r', edgecolor='black', linewidth=1, alpha=1, label='Male')
plt.scatter(occupation.Major_Occupation, occupation.Female_Estimate, s=200, c='b', edgecolor='black', linewidth=1, alpha=1, label='Female')
plt.title('Estimate Comparison for Male and Female: 2019', fontdict={'fontname':'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.ylabel('Estimate',fontdict={'fontsize':20})
plt.xlabel=('Occupation')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Percent Distribution of Overseas Filipino Workers by Region 2019-2020

# %%
url = "https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Overseas%20Filipino%20Worker%20by%20Region%202019-2020.csv"
