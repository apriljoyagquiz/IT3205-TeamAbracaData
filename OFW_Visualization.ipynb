# %% [markdown]
# <a href="https://colab.research.google.com/github/apriljoyagquiz/IT3205-TeamAbracaData/blob/main/OFW_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Overseas Filipino Workers 2019-2020**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import seaborn as sns
import seaborn

# %% [markdown]
# ## **Percent Distribution of Age Group by Sex of Overseas Filipino Workers 2019-2020**
#
#
# *Source: Philippine Statistics Authority*
#
# *   The following data provides information about the age group by sex of our overseas filipino workers from the year 2019-2020. This datasets helps the researcher to visualize the estimate population of our OFW's and draw conclusions.

# %%
url = 'https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Filipino%20Overseas%20Workers%20by%20Sex%20and%20Group%20Age%20Group%20by%202019%20and%202020.csv'
data = pd.read_csv(url)
display(data.iloc[0:])
# Out:
#      Age_Group  Both_Sexes_Estimate_2019  Male_Estimate_19  \
# 0      15 - 24                       6.3               5.5
# 1      25 - 29                      20.3              18.8
# 2      30 - 34                      22.3              19.5
# 3      35 - 39                      18.8              18.0
# 4      40 - 44                      14.2              16.4
# 5  45 and over                      18.0              21.8
#
#    Female_Estimate_19  Both_Sexes_Estimate_2020  Male_Estimate_20  \
# 0                 7.0                       3.8               2.9
# 1                21.6                      19.0              18.9
# 2                24.6                      22.4              21.2
# 3                19.5                      20.5              18.0
# 4                12.5                      15.2              15.6
# 5                14.9                      19.1              23.3
#
#    Female_Estimate_20
# 0                 4.4
# 1                19.0
# ...

# %%
#Getting all of the values from dataframe
Age_Group = data['Age_Group']
Male_Estimate_19 = data ['Male_Estimate_19']
Female_Estimate_19 = data ['Female_Estimate_19']

xpos =np.arange(len(Age_Group))

# %%
#Changing the size of the visualization
style.use ('ggplot')
plt.figure(figsize=(12,7))
barWidth = 0.3

#Creating the plot
plt.bar(xpos, Male_Estimate_19, color='#316879', width =barWidth, label='Male in 2019' )
plt.bar(xpos+0.3, Female_Estimate_19, color='#f47a60', width =barWidth, label='Female in 2019' )
plt.title("Male and Female Estimate in 2019", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':25})
plt.xticks(xpos+0.1,('15-24', '25-29', '30-34', '35-39', '40-44', '45 and over'))
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Estimate', fontsize=15)
plt.yticks()
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
# > <p align=justify> The bar graph illustrates the estimated number of male and female OFWs in the Philippines in 2019 and the percentage of age group by sex of overseas Filipino workers. The y-axis portrays the estimated sexes of 2019 overseas Filipino workers, while the x-axis shows the age group. The bar graph has been color-coded; the medium-dark cyan bar represents males, and the light red bar represents females. The chart shows that female overseas workers having 24.6 percent outnumber the males aged 30-34, which is 19.5 in Year 2019. By the age of 15-24, it is the least estimated for both sexes, which males having a percentage of 5.5 and women having a rate of 7.0</p>

# %%
#getting the values from the df
Age_Group = data['Age_Group']
Male_Estimate_20 = data ['Male_Estimate_20']
Female_Estimate_20 = data ['Female_Estimate_20']

xpos =np.arange(len(Age_Group))

# %%
#Changing the size of the visualization
style.use ('ggplot')
plt.figure(figsize=(12,7))
barWidth = 0.3

#Creating the plot
plt.bar(xpos, Male_Estimate_20, color='#E3B448', width =barWidth, label='Male in 2020' )
plt.bar(xpos+0.3, Female_Estimate_20, color='#3A6B35', width =barWidth, label='Female in 2020' )
plt.title("Male and Female Estimate in 2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':25})
plt.xticks(xpos+0.1,('15-24', '25-29', '30-34', '35-39', '40-44', '45 and over'))
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Estimate', fontsize=15)
plt.yticks()
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
# > <p align=justify> The bar graph presented is entitled the "Male and Female Estimate in 2020".As shown in the diagram, the Male and Female Estimate in 2020 in OFW varies according to their age. The y-axis is represented by the Estimated No; on the other hand, the x-axis is composed of their age. The age of 30-34 has the highest Female estimated No of OFW in the year 2020, which has 23.3 percent, and the age of 15-24 has the lowest female estimated OFW in 2020, which has 4.4 percent. While in the estimated male OFW, the age of 45 and over has the highest estimated OFW in 2020, which has a percentage of 23.3. In contrast, the age of 15-24 is the lowest estimate with a percentage of 2.9. </p>

# %%
#getting values from the df
Age_Group = data['Age_Group']
Both_Sexes_Estimate_2019 = data ['Both_Sexes_Estimate_2019']
Both_Sexes_Estimate_2020 = data ['Both_Sexes_Estimate_2020']

xpos =np.arange(len(Age_Group))

# %%
#Changing the size of the visualization
style.use ('ggplot')
plt.figure(figsize=(12,7))
barWidth = 0.3

#Creating the plot
plt.bar(xpos, Both_Sexes_Estimate_2019, color='#14213D', width =barWidth, label='Both Sexes in 2019' )
plt.bar(xpos+0.3, Both_Sexes_Estimate_2020, color='#FCA311', width =barWidth, label='Both Sexes in 2020' )
plt.title("Both Sexes Estimate in 2019 and 2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':25})
plt.xticks(xpos+0.1,('15-24', '25-29', '30-34', '35-39', '40-44', '45 and over'))
plt.xlabel('Age Group', fontsize=15)
plt.ylabel('Estimate', fontsize=15)
plt.yticks()
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
# > <p align=justify> The bar graph presented is entitled the "Both Sexes Estimate in 2019 and 2020". As shown in the diagram, the Both Sexes Estimate in 2019 and 2020 in OFW varies according to their age. The Estimated No represents the y-axis; on the other hand, the x-axis is composed of their age. The age of 30-34 in 2020 has the highest of both sexes' estimated No of OFW, and the age of 15-24 has the lowest of both sexes' estimated value OFW 2020. While in the year 2019, the estimated value OFW for the age of 30-34 has the highest estimated OFW. In contrast, the age of 15-24 is the lowest male OFW in 2019. </p>

# %% [markdown]
# ## **Occupation of Overseas Filipino Workers: 2019-2020**

# %% [markdown]
# *Source: Philippine Statistic Authority
#
#
#
# *   The following data will provide a salient information about the percentage distribution of overseas filipino workers by occupation year 2019-2020. This data will be used in analyzing which occupation has the highest percentage estimate and which occupation has the least.

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Overseas%20Filipino%20Workers%20by%20Occupation%202019-2020.csv'

# %%
occupation = pd.read_csv(url)
display(occupation.iloc[0:])
# Out:
#                                     Major_Occupation  \
# 0                                           Managers
# 1                                      Professionals
# 2            Technicians and associate professionals
# 3                           Clerical support workers
# 4                          Service and sales workers
# 5  Skilled agricultural forestry and fishery workers
# 6                    Craft and related trade workers
# 7         Plant and machine operators and assemblers
# 8                             Elementary occupations
#
#    Both_Sexes_Estimate_2019  Male_Estimate  Female_Estimate  \
# 0                       1.1            1.1              1.1
# 1                       8.5            6.9              9.8
# 2                       8.9           17.4              2.0
# 3                       3.5            3.1              3.8
# 4                      17.6           17.3             17.8
# 5                       0.8            1.8              0.1
# ...

# %%
#Changing the size of the visualization
plt.figure(figsize=(35,15))

#Creating the plot
plt.plot(occupation.Major_Occupation, occupation.Male_Estimate, 'c.-', label='Male', linewidth = 10)
plt.plot(occupation.Major_Occupation, occupation.Female_Estimate, 'm',label='Female', linewidth = 10)
plt.xlabel=("Major Occupation")
plt.ylabel("Estimates", fontdict={'fontsize':25})
plt.title("Estimate Comparison for Male and Female:2019", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.grid(color='green', linestyle='--', linewidth = 1)
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The graph illustrates the Percentage Distribution of Overseas Filipino Workers in 2019 by Major Occupation Group and Sex. The y-axis illustrates the key major occupations, whereas the x-axis represents the estimated number of Overseas Filipino Workers. In 2019, elementary occupations are the greatest number of OFWs. This is followed by those employed in service and sales, and then by Filipinos employed as plant and machine operators and assemblers.
#
#
#
# > <p align=justify> The majority of female OFWs, 62.1 percent, worked in elementary occupations, while 17.8 percent worked in service and sales. While among male OFWs, the following occupations had the highest proportion of workers: plant and machine operators and assemblers (24.6 percent), craft and related trades workers (17.4 percent), technicians and associate professionals (17.4 percent), service and sales workers (17.3 percent), and elementary occupations (10.4 percent).</p>

# %%
#Size of the entire graph
f = plt.figure()
f.set_figwidth(32)
f.set_figheight(15)
plt.grid(linewidth=1, color='green', linestyle='--')

#Creating the plot
plt.scatter(occupation.Major_Occupation, occupation.Male_Estimate_20, s=200, c='y', edgecolor='black', linewidth=1, alpha=1, label='Male')
plt.scatter(occupation.Major_Occupation, occupation.Female_Estimate_20, s=200, c='g', edgecolor='black', linewidth=1, alpha=1, label='Female')
plt.title('Estimate Comparison for Male and Female: 2020', fontdict={'fontname':'DejaVu Sans','fontweight':'bold', 'fontsize':35})
plt.ylabel('Estimate',fontdict={'fontsize':20})
plt.xlabel=('Occupation')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Interpretation:
#
# > <p align=justify> The graph illustrates the Percentage Distribution of Overseas Filipino Workers in 2020 by Major Occupation Group and Sex. The y-axis illustrates the key major occupations, whereas the x-axis represents the estimated number of Overseas Filipino Workers. In 2020, elementary occupations are the greatest number of OFWs. This is followed by those employed in service and sales, and then by Filipinos employed as plant and machine operators and assemblers.
#
# > <p align=justify>The majority of female OFWs, (70.3 percent), worked in elementary occupations, while (12.6 percent) worked in service and sales. While among male OFWs, the following occupations had the highest proportion of workers: plant and machine operators and assemblers (26.0 percent), service and sales workers (17.0 percent), craft and related trades workers (15.9 percent), technicians and associate professionals (13.9 percent), and elementary occupations (12.0 percent). </p>

# %%
#Changing the size of the visualization
plt.figure(figsize=(35,15))

#Creating the plot
plt.plot(occupation.Major_Occupation, occupation.Both_Sexes_Estimate_2019, 'y.-', label="male", linewidth = 10)
plt.plot(occupation.Major_Occupation, occupation.Both_Sexes_Estimate_2020, 'k', label="female", linewidth = 10)
plt.xlabel=("Major Occupation")
plt.ylabel("Estimates", fontdict={'fontsize':25})
plt.title("Estimate Comparison for Both Sexes: 2019-2020", fontdict={'fontname': 'Dejavu Sans','fontweight':'bold', 'fontsize':35})
plt.grid(color='green', linestyle='--', linewidth = 1)
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>In 2019 and 2020, the graph shows the percentage distribution of abroad Filipino employees by main occupational group and gender. The x-axis displays the estimated number of Overseas Filipino Workers, while the y-axis depicts the most important major jobs. The majority of OFWs are employed in primary jobs in 2019. Following that are Filipinos working in service and sales, plant and machine operators, and assemblers. The majority of OFWs will be employed in Elementary Occupations by 2020. </p>

# %% [markdown]
# ## **Percent Distribution of Overseas Filipino Workers by Region 2019-2020**

# %% [markdown]
# *Source: Philippine Statistic Authority
#
#
#
# *   The following data will provide a key information about the percentage distribution of overseas Filipino workers by region year 2019-2020. This data will be used in analyzing which region has the highest percentage estimate and which region has the least.

# %%
#Dataframe
url = "https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Percent%20Distribution%20of%20Overseas%20Filipino%20Worker%20by%20Region%202019-2020.csv"

# %%
region = pd.read_csv(url)

# %%
display(region)
# Out:
#                                                Region  Both_Sexes_in_2019  \
# 0                       National Capital Region (NCR)                 9.9
# 1              Cordillera Administrative Region (CAR)                 1.8
# 2                            Region I (Ilocos Region)                 8.6
# 3                          Region II (Cagayan Valley)                 6.1
# 4                          Region III (Central Luzon)                13.7
# 5                            Region IV-A (CALABARZON)                21.8
# 6                                     MIMAROPA Region                 1.4
# 7                             Region V (Bicol Region)                 3.8
# 8                         Region VI (Western Visayas)                 8.7
# 9                        Region VII (Central Visayas)                 5.0
# 10                      Region VIII (Eastern Visayas)                 2.0
# 11                    Region IX (Zamboanga Peninsula)                 1.4
# ...

# %%
#Getting all the values from the datasets
Region = region["Region"]
Male_Estimate = region["Male_Estimate"]
Female_Estimate = region["Female_Estimate"]

xpos = np.arange(len(Region))

# %%
#Changing the entire size of the visualization
style.use('ggplot')
plt.figure(figsize=(15,10))
barWidth = 0.2

#Plotting of data
plt.bar(xpos, Male_Estimate, color='indigo', width =barWidth, label='Male Estimate')
plt.bar(xpos+0.4, Female_Estimate, color='deeppink', width =barWidth, label='Female Estimate')

plt.xticks(xpos+0.4,('NCR', 'CAR', 'I', 'II', 'III', 'IV-A', 'IV-B', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 'XI', 'XII', 'XIII', 'BARMM'))
plt.ylabel('Estimate', fontsize=20)
plt.title("Estimate Comparison for Male and Female: 2019", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':20})
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The bar graph presented is entitled the "Estimate Comparison for Male and Female: 2019", which showcases the Comparison for Male and Female 2019 per region based on specific categories. As shown in the diagram, the Estimated No of OFW in the Philippines varies according to its region. The y-axis is represented by the estimated no. of male and female; on the other hand, the x-axis is composed of the region. The bar graphs are categorized by their color. The indigo bars indicate Male Estimate; and the deeppinkyellow bars are for Female Estimate. Based on the graph, the Calabarzon (IV-A)  has the highest Estimated No of OFW for male (25.0 percent) and female (19.3 percent) across the country in all the categories mentioned. In contrast, the Mimaropa Region has the lowest estimate for male (1.4 percent) and female (1.3 percent). Furthermore, the Zamboanga Region (Region IX) has the lowest Male Estimated (1.1 percent) in 2019, while the Mimaropa Region (Region IV-B) has the lowest Female Estimated (1.3 percent) No of OFW in the year 2019. </p>

# %%
#retrieving data
Region = region["Region"]
Male_Estimate_20 = region["Male_Estimate_20"]
Female_Estimate_20 = region["Female_Estimate_20"]
xpos = np.arange(len(Region))

# %%
#changing the size of the visualization
style.use('ggplot')
plt.figure(figsize=(15,10))
barWidth = 0.2
plt.rcParams['axes.facecolor'] = '#F2F2F2'
#plotting
plt.bar(xpos, Male_Estimate_20, width =barWidth, label='Male Estimate', color = '#292421')
plt.bar(xpos+0.4, Female_Estimate_20, width =barWidth, label='Female Estimate', color = '#FF8C00')

plt.xticks(xpos+0.4,('NCR', 'CAR', 'I', 'II', 'III', 'IV-A', 'IV-B', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 'XI', 'XII', 'XIII', 'BARMM'))
plt.ylabel('Estimate')
plt.title("Estimate Comparison for Male and Female: 2020", fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':20})
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The bar graph presented is entitled the "Estimate Comparison for Male and Female: 2020", which showcases the Comparison for Male and Female 2020 per region based on specific categories. As shown in the diagram, the Estimated No of OFW in the Philippines varies according to its region. The y-axis is represented by the estimated no. of male and female; on the other hand, the x-axis is composed of the region. The bar graphs are categorized by their color. The black indicate Male Estimate; and the darkorange bars are for Female Estimate. Based on the graph, the Calabarzon (IV-A) has the highest male Estimated No (22.4 percent) of OFW across the country in all the categories mentioned. In contrast, the BARMM Region has the lowest male estimated (0.6 percent) No of OFW. Furthermore, the Calabarzon (IV-A) has the highest Female Estimated No (15.0 percent) of OFW in the year 2020, while the Mimaropa Region (Region IV-B) has the lowest Female Estimated No (1.7) of OFW in the year 2020. </p>

# %% [markdown]
# ## **Annual Deployment of Overseas Filipino Workers by Sector and Remittances**
#
# Sources: Deployment statistics are from POEA; remittances are from Bangko Sentral ng Pilipinas.
#
#
#
# *   The following provides information about the annual deployment of Overseas Filipino Workers Year 1975-2010 from different sectors.

# %%
#Insert New Data Frame
deploy = pd.read_csv("https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Annual%20Deployment%20of%20Overseas%20Filipino%20Workers%20by%20Sector%20and%20Rmittances.csv")
deploy.head(14)
# Out:
#     Year  Land_Based  Sea_Based  Total_Deployed  Remittances
# 0   1975       12501      23534           36035       103.00
# 1   1976       19221      28614           47835       111.00
# 2   1977        3766      33699           37465       213.00
# 3   1978       50961      37280           88241       290.85
# 4   1979       92519      44818          137337       364.74
# 5   1980      157394      57196          214590       421.30
# 6   1981      210936      53307          264243       545.87
# 7   1982      250115      64169          314284       810.48
# 8   1983      380263      53594          433857       944.45
# 9   1984      300378      50604          350982       658.89
# 10  1985      320494      52290          372784       687.20
# 11  1986      323517      54697          378214       680.44
# 12  1987      382229      67042          449271       791.91
# 13  1988      357117      85913          443030       856.81

# %%
#Getting all data from the df
Year = deploy["Year"]
Land_Based = deploy["Land_Based"]
Sea_Based  = deploy["Sea_Based"]


#changing the size of the entire graph
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)


#Creating plots
y = [300000,  600000, 900000, 1200000]
plt.xticks(fontsize=12)
plt.yticks(y, fontsize=12)
plt.title("Deployment of OFW: Land Based -  Sea Based", fontweight="bold", fontsize=20)
plt.grid(color = 'white', linestyle = '--', linewidth = 0.8)
plt.plot(Year, Land_Based, 'o--', color="r", label="Land Based", lw=2.4)
plt.plot(Year, Sea_Based, 'o--', color="b", label="Sea Based", lw=2.4)
plt.ylabel("Number of Deployed OFWs", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The graph depicted OFW Deployment: Land-Based and Sea-Based, with the number of deployed OFWs and the year of their deployment indicated. The y-axis represents the number of deployed OFWs, and the x-axis represents the year of deployment. The line graphs are categorized by their color. The broken red line represents land-based, while the blue line represents sea-based. The chart shows that land-based deployments outnumber sea-based deployments. In 2010, both sea-based and land-based deployments of Overseas Filipino workers were higher. </p>

# %%
#Getting values from the df
Year = deploy["Year"]
Remittances = deploy["Remittances"]

#changing the size of the entire graph
f = plt.figure()
f.set_figwidth(23)
f.set_figheight(7)

#Plotting the data
plt.grid(color = 'green', linestyle = '--', linewidth = 0.3)
plt.scatter(Year, Remittances, s=200, c='m')
plt.title("Remittances: 1975-2010",  fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':25})
plt.ylabel("Remittance", fontsize=20)
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The "Remittances: 1975-2010" scatter plot depicts the highest and lowest remittances between 1975 and 2010. The number of remittances corresponding to each year is depicted in the diagram. The years are represented on the x-axis, while the remittances are represented on the y-axis. The dispersed violet dots on the graph show remittance growth and their respective year. The highest remittances were received in 2010, while the lowest remittances were received in 1975. </p>

# %% [markdown]
# ## **Welfare Cases by Age, January-June 2011**
# Source: Data provided by the Repatriation and Assistance Division, OWWA
#
#
# *  The following data provides information about different welfare cases categorized by age group from January-June 2011.

# %%
url = "https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Welfare-Cases%20by%20Age%20January-June%202011.csv"
welfare = pd.read_csv(url)
display(welfare)
# Out:
#              Welfare Case  25 years old  24 years old  23 years old  \
# 0            Maltreatment            32            17            22
# 1    Non payment of wages            50            22            14
# 2  Poor working condition            20            14            13
# 3             Overstaying             4             3             4
# 4       Civil war (Libya)             3             3             3
# 5           Other reasons            17             7             7
#
#    15-22 years old
# 0               25
# 1               26
# 2               20
# 3                5
# 4                4
# 5               10

# %%
#inputting values
maltreatment = (32, 27, 22, 25)
Nonpayment_of_wages = (50, 22, 14, 26)
poor_working_condition = (20, 14, 13, 20)
overstaying= (4, 3, 4, 5)
Civil_war = (3, 3, 3, 4)

# %%
#changing the size of the plot
style.use('ggplot')
plt.figure(figsize=(10,7))
barWidth = 0.2
#plotting the data
xpos = np.array([25, 24, 23, 22])
plt.bar(xpos, maltreatment, color='royalblue', width =barWidth, label='Maltreatment')
plt.bar(xpos+0.2, Nonpayment_of_wages, color='red', width =barWidth, label='Non_payment')
plt.bar(xpos+0.4, poor_working_condition, color='purple', width =barWidth, label='Poor_working_condition')
plt.bar(xpos+0.6, overstaying, color='yellow', width =barWidth, label='Overstaying')
plt.bar(xpos+0.8, Civil_war, color='orange', width =barWidth, label='Civil_war')
plt.xticks(xpos + 0.2, ((('25','24', '23', '15-22'))))
plt.ylabel("No of Cases")
plt.title('Welfare Cases', fontdict={'fontname': 'DejaVu Sans', 'fontsize': 18})
plt.legend()
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify>The bar graph presented is entitled the "Welfare Cases", which showcases the welfare cases in OFW per age based on specific categories.As shown in the diagram, the welfare cases in OFW varies according to their age. The y-axis is represented by the No. of Cases; on the other hand, the x-axis is composed of their age. The bar graphs are categorized by their color.The royalblue bars indicate Maltreatment; the red bars are for non_payment; the purple bars for Poor_working_condition ; the yellow bars for Overstaying and lastly, the orange bars indicate Civil_war. Based on the graph,that in the range 25 year olds have the highest No of cases in all the range of age mentioned in allcategories.In contrast, the age of 23 has the lowest.Furthermore, the age of 24 has the lowest Overstaying welfare cases, while the 23 years old has the lowest Maltreatment no of case.There are three(3) ranges of age have an equal no of cases in Civil_war cases: the 23 , 24 and 25 years old. </p>

# %% [markdown]
# ## **Percent Distribution of COVID-19 Cases Among Overseas Filipino Workers**

# %% [markdown]
# Source: DOLE-POLO
#
# The following data will provide a key information about the percentage distribution of covid-19 cases among overseas Filipino workers.

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Table%202.%20Number%20of%20Affected%20OFWs%20during%20the%20Pandemic.csv'

# %%
data = pd.read_csv(url)
display(data.iloc[0:])
# Out:
#             Covid_Cases Number_of_OFWs
# 0              Infected         17,721
# 1            Recoveries         10,218
# 2  Undergoing Treatment          6,560
# 3                Deaths            943

# %%
import matplotlib.pyplot as plt

labels= ['Undergoing Treatment', 'Deaths', 'Recoveries', 'Infected']
colors=['#20639b', '#3CAEA3', '#F6D55C', '#ED553B']

sizes= [6560, 943, 10218, 17721]
plt.figure(figsize = (7,6))
plt.pie(sizes,labels=labels, colors=colors, startangle=90, shadow=True,explode=(0.1, 0.1, 0.1, 0.0), autopct='%1.2f%%')

plt.axis('equal')
plt.title('OFW Covid-19 Cases\n', fontdict={'fontname': 'DejaVu Sans','fontweight':'bold', 'fontsize':20})
plt.legend(labels,loc=1)
plt.show()

# %% [markdown]
# ## Interpretation:
#
#
# > <p align=justify> The pie chart depicts the distribution of OFW Covid-19 cases as follows: Undergoing Treatment, Deaths, Recoveries, and Infected. Each case is depicted in a different color to provide differentiation. Infected, shown in dark red, has the highest percentage allocation of 50.00 percent, indicating that the number of infected OFWs is greater. Deaths, on the other hand, have a minimum allocation percentage of 2.66 percent. </p>

# %% [markdown]
# ## **Linear Regression and Correlation Analysis**
# *Source: Deployment statistics are from POEA; remittances are from Bangko Sentral ng Pilipinas.*
#
#
#
# *   The following data has been subjected to data analysis techniques and procedures in order to provide an output that can be utilized to generate interpretations and assess the number of OFWs deployed in various sectors. Correlation analysis was also used to determine the linear correlations between the two variables.

# %%
#Insert New Data Frame
Deploy = pd.read_csv("https://raw.githubusercontent.com/apriljoyagquiz/IT3205-TeamAbracaData/main/Datasets/Annual%20Deployment%20of%20Overseas%20Filipino%20Workers%20by%20Sector%20and%20Rmittances.csv")
Deploy.head(14)
# Out:
#     Year  Land_Based  Sea_Based  Total_Deployed  Remittances
# 0   1975       12501      23534           36035       103.00
# 1   1976       19221      28614           47835       111.00
# 2   1977        3766      33699           37465       213.00
# 3   1978       50961      37280           88241       290.85
# 4   1979       92519      44818          137337       364.74
# 5   1980      157394      57196          214590       421.30
# 6   1981      210936      53307          264243       545.87
# 7   1982      250115      64169          314284       810.48
# 8   1983      380263      53594          433857       944.45
# 9   1984      300378      50604          350982       658.89
# 10  1985      320494      52290          372784       687.20
# 11  1986      323517      54697          378214       680.44
# 12  1987      382229      67042          449271       791.91
# 13  1988      357117      85913          443030       856.81

# %%
#View columns (copy and paste to make new dataframe)
Deploy.columns
# Out:
# Index(['Year', 'Land_Based', 'Sea_Based', 'Total_Deployed', 'Remittances'], dtype='object')

# %%
#New dataframe
Deploy = Deploy[['Year', 'Land_Based', 'Sea_Based', 'Remittances']]
Deploy.head()
# Out:
#    Year  Land_Based  Sea_Based  Remittances
# 0  1975       12501      23534       103.00
# 1  1976       19221      28614       111.00
# 2  1977        3766      33699       213.00
# 3  1978       50961      37280       290.85
# 4  1979       92519      44818       364.74

# %%
Deploy.tail()
# Out:
#     Year  Land_Based  Sea_Based  Remittances
# 31  2006      788070     274497     12761.31
# 32  2007      811070     266553     14449.93
# 33  2008      974399     261614     16426.85
# 34  2009     1092162     330424     17348.05
# 35  2010     1123676     347150     18762.98

# %%
Deploy.corr()
# Out:
#                  Year  Land_Based  Sea_Based  Remittances
# Year         1.000000    0.969370   0.976730     0.893495
# Land_Based   0.969370    1.000000   0.960365     0.907251
# Sea_Based    0.976730    0.960365   1.000000     0.941596
# Remittances  0.893495    0.907251   0.941596     1.000000

# %%
Deploy.describe()
# Out:
#               Year    Land_Based      Sea_Based   Remittances
# count    36.000000  3.600000e+01      36.000000     36.000000
# mean   1992.500000  4.836202e+05  144131.611111   4800.551389
# std      10.535654  2.899204e+05   91627.508302   5430.599904
# min    1975.000000  3.766000e+03   23534.000000    103.000000
# 25%    1983.750000  3.154650e+05   54421.250000    685.510000
# 50%    1992.500000  4.887165e+05  141132.000000   2215.980000
# 75%    2001.250000  6.626480e+05  205841.500000   7006.692500
# max    2010.000000  1.123676e+06  347150.000000  18762.980000

# %% [markdown]
# ## **Seaborn Correlation Heatmap**

# %%
plt.figure(figsize=(10,8))
seaborn.heatmap(Deploy.corr(), annot=True, cmap="rocket_r")
plt.title('Correlation Matrix for Number of Deployed OFWs')
plt.show()

# %% [markdown]
# ## **Matplotlib Correlation Heatmap**

# %%
plt.imshow(Deploy.corr(),cmap = "crest", interpolation='none')
plt.colorbar()
plt.xticks(range(len(Deploy.columns)), Deploy.columns, rotation = 90)
plt.xticks(range(len(Deploy.columns)), Deploy.columns)
plt.gcf().set_size_inches(10,8)

labels = Deploy.corr().values
for y in range(labels.shape[0]):
    for x in range(labels.shape[1]):
        plt.text(x,y,'{:.2f}'.format(labels[y,x]), ha = 'center',va='center', color='white')

# %% [markdown]
# > <p align=justify> I tried to explore how to plot correlation heatmap using two libraries from python. And if you want to plot with a little line of code, try to consider using seaborn instead of matplotlib. </p>

# %% [markdown]
# #### **Positive Correlation Features:**
#
#
# *   Year and Land Based: 0.97
# *   Year and Sea Based: 0.98
# *   Year and Remittances: 0.89

# %%
sns.pairplot(Deploy, palette='husl')
plt.show()

# %% [markdown]
# > <p align=justify> The Pair Plot aids in the visualization of single-variable distributions as well as relationships between two variables.</p>

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ### **Year vs Land Based**

# %%
#Linear Regression
sns.lmplot(x="Year", y="Land_Based", data=Deploy)
plt.title("\n Relationship Between Year and Land Based", fontweight="bold")
plt.show()

# %% [markdown]
# > Because the calculated correlation value is 0.97, this indicates that these two variables have a strong positive relationship. This only conclude that as years goes by, the number of deployed Overseas Filipino Workers from Land Sector also increases.

# %% [markdown]
# ### **Year vs Sea Based**

# %%
#Linear Regression
sns.lmplot(x="Year", y="Sea_Based", data=Deploy)
plt.title("\n Relationship Between Year and Sea Based", fontweight="bold")
plt.show()

# %% [markdown]
# > The correlation between these two variables year and deployed OFWs in the sea sector is very high. Similar to the previous interpretation, the number of our "kababayan" who works abroad increases as the year goes by.

# %% [markdown]
# ### **Year vs Remittances**

# %%
#Linear Regression
sns.lmplot(x="Year", y="Remittances", data=Deploy)
plt.title("\n Relationship Between Year and Remittances", fontweight="bold")
plt.show()

# %% [markdown]
# > <p align=justify> This graph depicts the relationship between year and remittance and the contribution of OFWs to the country's economic remittances in those years. It shows how remittances increase with each passing year in those years. </p>
